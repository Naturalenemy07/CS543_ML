# %%
import pandas as pd
datapath = '/home/raven/Documents/CS/CS543_ML/mlvenv/lib/python3.10/site-packages/ISLP/data/'

# %%
advert = pd.read_csv(datapath+"Advertising.csv")

# %%
advert
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
pd.plotting.scatter_matrix(advert,figsize=(12,12))
# Out:
# array([[<Axes: xlabel='Unnamed: 0', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='TV', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='radio', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='newspaper', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='sales', ylabel='Unnamed: 0'>],
#        [<Axes: xlabel='Unnamed: 0', ylabel='TV'>,
#         <Axes: xlabel='TV', ylabel='TV'>,
#         <Axes: xlabel='radio', ylabel='TV'>,
#         <Axes: xlabel='newspaper', ylabel='TV'>,
#         <Axes: xlabel='sales', ylabel='TV'>],
#        [<Axes: xlabel='Unnamed: 0', ylabel='radio'>,
#         <Axes: xlabel='TV', ylabel='radio'>,
#         <Axes: xlabel='radio', ylabel='radio'>,
#         <Axes: xlabel='newspaper', ylabel='radio'>,
#         <Axes: xlabel='sales', ylabel='radio'>],
#        [<Axes: xlabel='Unnamed: 0', ylabel='newspaper'>,
#         <Axes: xlabel='TV', ylabel='newspaper'>,
#         <Axes: xlabel='radio', ylabel='newspaper'>,
# ...
